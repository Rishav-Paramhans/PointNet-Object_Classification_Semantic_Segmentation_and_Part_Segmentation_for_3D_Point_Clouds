# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from csv import DictReader

# %% [markdown]
# # Average Training Loss and Average Training Accuracy

# %%
train_data = pd.read_csv('training.csv')
training_loss= train_data['train_loss']
epoch= train_data['epoch']
training_accuracy= train_data['accuracy']

# %%
avg_error= []
for i in range(120):
    sum=0
    for a in range(len(training_loss)):
        if(i == epoch[a]):
            sum+= training_loss[a]
        else:
            pass
    avg= sum/246
    avg_error.append(avg)

# %%
print(len(avg_error))
# Out:
# 120

# %%
avg_train_accuracy=[]
for i in range(120):
    sum=0
    for a in range(len(training_accuracy)):
        if(i == epoch[a]):
            sum+= training_accuracy[a]
        else:
            pass
    avg= sum/246
    avg_train_accuracy.append(avg)

# %%
print((avg_train_accuracy))
# Out:
# [0.4458841463414634, 0.5810467479674797, 0.65625, 0.7000762195121951, 0.7290396341463414, 0.7648628048780488, 0.7738821138211383, 0.7865853658536586, 0.7991615853658537, 0.8020833333333334, 0.8198678861788617, 0.8175813008130082, 0.8391768292682927, 0.8408282520325203, 0.8408282520325203, 0.8545477642276422, 0.8575965447154471, 0.8577235772357723, 0.8652184959349594, 0.8920223577235772, 0.9029471544715447, 0.8934197154471545, 0.9011686991869918, 0.9099339430894309, 0.9053607723577236, 0.9167936991869918, 0.9152693089430894, 0.9151422764227642, 0.916285569105691, 0.9193343495934959, 0.9217479674796748, 0.9249237804878049, 0.9203506097560976, 0.9239075203252033, 0.9178099593495935, 0.930005081300813, 0.9259400406504065, 0.9249237804878049, 0.930005081300813, 0.9451219512195121, 0.9516006097560976, 0.9489329268292683, 0.9523628048780488, 0.9507113821138211, 0.9549034552845529, 0.9550304878048781, 0.9547764227642277, 0.9568089430894309, 0.9585873983739838, 0.9616361788617886, 0.9588414634146342, 0.9597306910569106, 0.9632876016260162, 0.9594766260162602, 0.958079268292683, 0.963795731707317, 0.959349593495935, 0.9658282520325203, 0.9649390243902439, 0.9729420731707317, 0.9711636178861789, 0.9705284552845529, 0.9734502032520326, 0.9761178861788617, 0.9738313008130082, 0.9759908536585366, 0.9770071138211383, 0.9740853658536586, 0.9767530487804879, 0.979420731707317, 0.9744664634146342, 0.9780233739837398, 0.9778963414634146, 0.9804369918699187, 0.9785315040650406, 0.9800558943089431, 0.9799288617886179, 0.9754827235772358, 0.9799288617886179, 0.9809451219512195, 0.9834857723577236, 0.983104674796748, 0.9832317073170732, 0.9838668699186992, 0.9883130081300813, 0.9832317073170732, 0.9822154471544715, 0.9872967479674797, 0.985645325203252, 0.983739837398374, 0.9865345528455285, 0.9857723577235772, 0.9855182926829268, 0.9861534552845529, 0.9839939024390244, 0.9857723577235772, 0.9853912601626016, 0.9858993902439024, 0.9853912601626016, 0.9866615853658537, 0.9881859756097561, 0.9875508130081301, 0.9885670731707317, 0.9886941056910569, 0.9879319105691057, 0.9874237804878049, 0.9878048780487805, 0.9879319105691057, 0.9881859756097561, 0.9878048780487805, 0.9886941056910569, 0.9886941056910569, 0.9885670731707317, 0.9880589430894309, 0.989329268292683, 0.9888211382113821, 0.9885670731707317, 0.9890752032520326, 0.9889481707317073, 0.9903455284552846]

# %% [markdown]
# # Average Validation Error and Average Validation Accuracy

# %%
validation_data= pd.read_csv('validation.csv')
validation_loss= validation_data['validation_loss']
epoch_val= validation_data['epoch']

# %%
len(validation_loss)
# Out:
# 3000

# %%
avg_validation_error= []
for i in range(120):
    sum=0
    for a in range(len(validation_loss)):
        if(i == epoch_val[a]):
            sum+= validation_loss[a]
        else:
            pass
    avg_val= sum/25
    avg_validation_error.append(avg_val)

# %%
print(avg_validation_error)
# Out:
# [2.2269564151763914, 1.494274950027466, 1.1636840176582337, 1.0894894528388976, 0.9421870338916779, 0.8951260864734649, 0.8058204674720764, 0.7304132390022278, 0.6797736096382141, 0.7628658664226532, 0.7522123312950134, 0.7525437170267105, 0.6127861785888672, 0.6909154105186462, 0.6957501351833344, 0.5441215264797211, 0.5908667093515396, 0.5456168359518051, 0.5653656816482544, 0.3718889257311821, 0.4837776780128479, 0.5144289559125901, 0.4831366771459579, 0.3914207059144974, 0.469446439743042, 0.45040231227874755, 0.46819295823574064, 0.5358640664815902, 0.4810172283649445, 0.428068685233593, 0.4370077568292618, 0.45148736745119095, 0.4874715119600296, 0.5491187161207199, 0.5486845031380654, 0.5158716267347336, 0.4808588767051697, 0.44219616055488586, 0.4512843573093414, 0.5127403245866299, 0.48538542956113817, 0.48593892365694047, 0.536714848279953, 0.5179546642303466, 0.4545317881181836, 0.4187520706653595, 0.44509410455822945, 0.4142167440056801, 0.5484426353871822, 0.4854171484708786, 0.5017115406692028, 0.5232494422793388, 0.44942054569721224, 0.44429793357849123, 0.5032227608561516, 0.5256421548128128, 0.5706844371557236, 0.5252753058075905, 0.5564171060919761, 0.5228692764043807, 0.3664417091012001, 0.5272102843225003, 0.5099779179692269, 0.3974036967754364, 0.43916905894875524, 0.4843277931213379, 0.5244363400340081, 0.5859469693899154, 0.5342315462231636, 0.4708153624087572, 0.5254373875260353, 0.5419574509561061, 0.3839471030235291, 0.5741614899039269, 0.4775760990381241, 0.5002551889419555, 0.5470759621262551, 0.5025523349642753, 0.5519040986895561, 0.5519941216707229, 0.5323406499624252, 0.5147658109664917, 0.4651885065436363, 0.4993113511241972, 0.6483890598267317, 0.5021497005224228, 0.5049591279774904, 0.5274714877456427, 0.6687112030386925, 0.5643350034952164, 0.5395753380656242, 0.6125382506847381, 0.633586575165391, 0.5720438657328486, 0.5239934474229813, 0.6007555150985717, 0.6122153699398041, 0.5101201443374157, 0.4993501519411802, 0.6845113433897495, 0.4647268714383245, 0.5194351330399514, 0.5009028591215611, 0.4256705114245415, 0.5399251169711351, 0.45782782360911367, 0.5267412567138672, 0.5423770117759704, 0.6102896535396576, 0.63106739372015, 0.5411768749542535, 0.49021562427282334, 0.6302869495749474, 0.5568393623828888, 0.591255487203598, 0.6133908635377884, 0.7851733386516571, 0.573520313501358, 0.6811272633075715, 0.50087291251868]

# %%
validation_accuracy= validation_data['accuracy']
len(validation_accuracy)
# Out:
# 3000

# %%
avg_validation_accuracy=[]
for i in range(120):
    sum=0
    for a in range(len(validation_accuracy)):
        if(i == epoch_val[a]):
            sum+= validation_accuracy[a]
        else:
            pass
    avg_acc= sum/25
    avg_validation_accuracy.append(avg_acc)

# %%
print(len(avg_validation_accuracy))
# Out:
# 120

# %% [markdown]
# # Plotting

# %%
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.plot(avg_error, label='Training_Error')
plt.plot(avg_validation_error, label= 'Validation_Error')
plt.grid()
plt.legend()

# %%
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.plot(avg_train_accuracy, label='Training_Accuracy')
plt.plot(avg_validation_accuracy, label='Validation_Accuracy')
plt.grid()
plt.legend()
