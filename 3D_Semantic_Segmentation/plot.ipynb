# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from csv import DictReader

# %% [markdown]
# # Average Training Loss and Average Training Accuracy

# %%
train_data = pd.read_csv('training.csv')
training_loss= train_data['train_loss']
epoch= train_data['epoch']
training_accuracy= train_data['accuracy']

# %%
avg_error= []
for i in range(120):
    sum=0
    for a in range(len(training_loss)):
        if(i == epoch[a]):
            sum+= training_loss[a]
        else:
            pass
    avg= sum/500
    avg_error.append(avg)

# %%
print(len(avg_error))
# Out:
# 120

# %%
avg_train_accuracy=[]
for i in range(120):
    sum=0
    for a in range(len(training_accuracy)):
        if(i == epoch[a]):
            sum+= training_accuracy[a]
        else:
            pass
    avg= sum/500
    avg_train_accuracy.append(avg)

# %%
print((avg_train_accuracy))
# Out:
# [0.7000088348388672, 0.7734374389648437, 0.8021834564208984, 0.8177784881591796, 0.8340137176513672, 0.8310907897949219, 0.8477678375244141, 0.860302963256836, 0.8660335235595703, 0.8705608367919921, 0.8773432922363281, 0.88413427734375, 0.8849097747802734, 0.8907220764160156, 0.8942290954589843, 0.8971909484863281, 0.9027946166992188, 0.883440933227539, 0.8980004577636719, 0.9146610107421875, 0.9187808990478515, 0.9217369079589843, 0.9241209411621094, 0.9256885375976562, 0.928442138671875, 0.9299241027832031, 0.9304630889892578, 0.9324886322021484, 0.9351057434082031, 0.93513720703125, 0.9361566619873047, 0.9381063385009766, 0.9351906585693359, 0.9388246612548828, 0.9419850921630859, 0.9424439697265625, 0.9432413635253907, 0.9435783843994141, 0.9449366912841797, 0.9492705841064453, 0.9511013641357422, 0.9517721405029297, 0.9521625366210937, 0.9528676300048828, 0.9538535461425781, 0.9542283325195312, 0.9544081115722656, 0.9549844970703125, 0.9544873352050781, 0.9554714965820312, 0.955867446899414, 0.9566696014404297, 0.957318130493164, 0.957862289428711, 0.9583089752197266, 0.9567237243652343, 0.9575853118896485, 0.9588246307373047, 0.9594177551269532, 0.9611357421875, 0.9622904052734375, 0.962012451171875, 0.9623697204589844, 0.9626674957275391, 0.96287255859375, 0.9627784729003906, 0.9633613891601562, 0.9636109008789062, 0.9633333892822266, 0.9639565582275391, 0.963861343383789, 0.9642584381103516, 0.9642287445068359, 0.9644803314208984, 0.9640281677246094, 0.9644870758056641, 0.965173812866211, 0.9648655853271484, 0.9651932525634765, 0.9661213989257813, 0.9657114562988282, 0.9667836151123047, 0.96648681640625, 0.9668903045654297, 0.9672275085449219, 0.9673260192871094, 0.967371337890625, 0.9672897796630859, 0.9674877166748047, 0.9675525360107422, 0.96752587890625, 0.9675490417480469, 0.9676217498779297, 0.9679725494384765, 0.9680005187988281, 0.9680200042724609, 0.96844384765625, 0.9682098999023437, 0.968255874633789, 0.968715560913086, 0.9686995239257813, 0.9688499450683594, 0.9690211181640624, 0.9690899963378906, 0.9693950500488281, 0.9691562042236328, 0.9691742706298828, 0.96930908203125, 0.9694870452880859, 0.9692622833251953, 0.9694689483642578, 0.9694289855957031, 0.9695318145751953, 0.969454116821289, 0.9696001281738281, 0.9696161499023438, 0.9697567596435547, 0.9698694915771484, 0.969541015625, 0.9700229034423828]

# %% [markdown]
# # Average Validation Error and Average Validation Accuracy

# %%
validation_data= pd.read_csv('validation.csv')
validation_loss= validation_data['validation_loss']
epoch_val= validation_data['epoch']

# %%
len(validation_loss)
# Out:
# 6000

# %%
avg_validation_error= []
for i in range(120):
    sum=0
    for a in range(len(validation_loss)):
        if(i == epoch_val[a]):
            sum+= validation_loss[a]
        else:
            pass
    avg_val= sum/50
    avg_validation_error.append(avg_val)

# %%
print(avg_validation_error)
# Out:
# [1.2395821714401245, 1.0026236844062806, 0.9278769981861115, 0.7749212038516998, 0.7218586385250092, 0.7911278104782105, 0.7220951187610626, 0.6711979150772095, 0.6633546364307403, 0.6352993839979172, 0.620611070394516, 0.6471178728342056, 0.6347434204816819, 0.5861153334379197, 0.5746183532476425, 0.5891878724098205, 0.5654670083522797, 0.7410083734989166, 0.5905809271335601, 0.4726061099767685, 0.4816305106878281, 0.46658231735229494, 0.5027028906345368, 0.4864612102508545, 0.4705517366528511, 0.46058355152606967, 0.5050039088726044, 0.4676467114686966, 0.48709685444831846, 0.5300481903553009, 0.47944892704486847, 0.4983036518096924, 0.5259606611728668, 0.4919558310508728, 0.489848935008049, 0.4875019776821137, 0.45156479597091675, 0.459527473449707, 0.46386452853679655, 0.4823018771409988, 0.4823986041545868, 0.4757722443342209, 0.4896868473291397, 0.47395329117774965, 0.4718854695558548, 0.46746584475040437, 0.48466325402259824, 0.4738608479499817, 0.49552034854888916, 0.49495995938777926, 0.4602878308296204, 0.504228595495224, 0.49610017776489257, 0.46471769630908966, 0.48286832869052887, 0.5222082024812699, 0.4805137550830841, 0.4929055055975914, 0.5220805519819259, 0.47260389804840086, 0.43654872715473175, 0.4565726351737976, 0.4895749795436859, 0.4477551940083504, 0.5548279982805252, 0.4931955486536026, 0.5003516787290573, 0.5121910968422889, 0.4782923632860184, 0.5161693474650383, 0.471787987947464, 0.5173737353086472, 0.500590655207634, 0.4772515743970871, 0.5306164455413819, 0.4976905596256256, 0.4708186215162277, 0.47458738684654234, 0.5039332604408264, 0.5163458776473999, 0.5410041570663452, 0.5092054107785224, 0.5019230735301972, 0.4655448579788208, 0.5061709779500961, 0.48090351283550264, 0.48721796154975894, 0.4924187356233597, 0.5347671213746071, 0.5297071480751038, 0.4719636633992195, 0.5254112562537193, 0.4815606606006622, 0.4832443380355835, 0.4619377365708351, 0.4991933751106262, 0.5031048482656479, 0.4972302848100662, 0.5170966759324074, 0.44604209542274476, 0.46960725843906403, 0.5399818110466004, 0.46975968658924105, 0.5032180482149125, 0.5066114577651024, 0.5612254393100738, 0.4800033330917358, 0.5114331597089767, 0.5063373672962189, 0.48958483815193177, 0.50835284948349, 0.5360642382502556, 0.512843383550644, 0.5069172647595406, 0.5509643146395683, 0.47313416838645933, 0.5038649892807007, 0.539281250834465, 0.5531723409891128, 0.537003467977047]

# %%
validation_accuracy= validation_data['accuracy']
len(validation_accuracy)
# Out:
# 6000

# %%
avg_validation_accuracy=[]
for i in range(120):
    sum=0
    for a in range(len(validation_accuracy)):
        if(i == epoch_val[a]):
            sum+= validation_accuracy[a]
        else:
            pass
    avg_acc= sum/50
    avg_validation_accuracy.append(avg_acc)

# %%
print(len(avg_validation_accuracy))
# Out:
# 120

# %% [markdown]
# # Plotting

# %%
plt.xlabel = "Epoch"
plt.ylabel= "Error"
plt.plot(avg_error, label= 'Training_Error')
plt.plot(avg_validation_error, label= 'Validation_Error')
plt.legend()
plt.grid()

# %%
plt.xlabel = "Epoch"
plt.ylabel= "Accuracy"
plt.plot(avg_train_accuracy, label= 'Train_Accuracy')
plt.plot(avg_validation_accuracy, label= 'Validation_Accurcay')
plt.legend()
plt.grid()
